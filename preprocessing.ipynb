# %% [markdown]
# ### Import các thư viện sử dụng

# %%
import os
import sys

module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Đọc dữ liệu thô từ file

# %%
raw_df = pd.read_csv('Data\\Youth_Tobacco_Survey__YTS__Data.csv')
raw_df.head()
# Out:
#    YEAR LocationAbbr LocationDesc                  TopicType  \
# 0  2008           AL      Alabama  Tobacco Use – Survey Data
# 1  2010           AL      Alabama  Tobacco Use – Survey Data
# 2  2002           AL      Alabama  Tobacco Use – Survey Data
# 3  2012           AL      Alabama  Tobacco Use – Survey Data
# 4  2004           AL      Alabama  Tobacco Use – Survey Data
#
#                        TopicDesc  \
# 0          Cigarette Use (Youth)
# 1          Cigarette Use (Youth)
# 2              Cessation (Youth)
# 3              Cessation (Youth)
# 4  Smokeless Tobacco Use (Youth)
#
#                                          MeasureDesc DataSource  Response  \
# 0                                     Smoking Status        YTS      Ever
# 1                                     Smoking Status        YTS  Frequent
# 2  Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# 3  Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# 4                                        User Status        YTS      Ever
#
#   Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0               %      Percentage  ...  (32.840571122, -86.631860762)
# 1               %      Percentage  ...  (32.840571122, -86.631860762)
# 2               %      Percentage  ...  (32.840571122, -86.631860762)
# 3               %      Percentage  ...  (32.840571122, -86.631860762)
# 4               %      Percentage  ...  (32.840571122, -86.631860762)
#
#   TopicTypeId TopicId  MeasureId  StratificationID1  StratificationID2  \
# 0         BEH  106BEH     166SSA               3GEN               8AGE
# 1         BEH  106BEH     166SSA               3GEN               8AGE
# 2         BEH  105BEH     169QUA               3GEN               8AGE
# 3         BEH  105BEH     169QUA               2GEN               8AGE
# 4         BEH  151BEH     169USS               2GEN               8AGE
#
#    StratificationID3 StratificationID4 SubMeasureID DisplayOrder
# 0               6RAC              2EDU        YTS08            8
# 1               6RAC              2EDU        YTS09            9
# 2               6RAC              2EDU        YTS06            6
# 3               6RAC              2EDU        YTS05            5
# 4               6RAC              1EDU        YTS11           11
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Kiểm tra chất lượng dữ liệu

# %%
print(f"Kích thước dữ liệu: {raw_df.shape}")

if raw_df.shape[0] > 1000:
    print(f"Dữ liệu tốt.")
else:
    print(f"Dữ liệu chưa tốt. Cần kiểm tra lại.")
# Out:
# Kích thước dữ liệu: (10600, 31)
# Dữ liệu tốt.

# %% [markdown]
# ### Kiểm tra các dòng dữ liệu
# #### Ý nghĩa của các dòng dữ liệu
# Trong tập dữ liệu này, mỗi dòng sẽ đại diện cho một mẫu khảo sát tại một bang ở một thời điểm nhất định (tính theo năm). Các thông tin quan trọng cần lưu ý trong mỗi dòng là: năm khảo sát (YEAR), địa điểm (LocationDesc), mô tả chủ đề khảo sát (TopicDesc), mô tả đơn vị đo lường (MeasureDesc), Phản hồi của người khảo sát (Response), Giá trị dữ liệu (Data_Value), Kí hiệu cước chú (Data_Value_Footnote_Symbol), Cước chú (Data_Value_Footnote), Độ lệch chuẩn của giá trị (Data_Value_Std_Err), Giới hạn thấp của độ tin cậy (Low_Confidence_Limit), Giới hạn cao của độ tin cậy (High_Confidence_Limit), Kích thước mẫu (Sample_Size), Giới tính (Gender), Trình độ giáo dục (Education). Không có các dòng có ý nghĩa khác nhau.

# %% [markdown]
# **TODO**: Give your obervation here
#
# cessation -> percent (1(overall), 2(male), 3(female)), quit attemp (4(overall), 5(male), 6(female))
# cigar use -> smoke status (7 (current), 8(ever), 9(freq))
# smokeless -> user status (10 (current), 11(ever), 12(freq))

# %% [markdown]
# #### Kiểm tra số dòng dữ liệu trùng lắp

# %%
num_duplicated_rows = sum(raw_df.duplicated())
if num_duplicated_rows == 0:
    print(f"Dữ liệu thô không có dòng trùng lắp.")
else:
    print(f"Dữ liệu thô có {num_duplicated_rows} dòng trùng lắp. Cần loại bỏ các dòng này.")
# Out:
# Dữ liệu thô không có dòng trùng lắp.

# %% [markdown]
# ### Kiểm tra các cột dữ liệu
# #### Kiểu dữ liệu của từng cột

# %%
dtypes = raw_df.dtypes
dtypes
# Out:
# YEAR                            int64
# LocationAbbr                   object
# LocationDesc                   object
# TopicType                      object
# TopicDesc                      object
# MeasureDesc                    object
# DataSource                     object
# Response                       object
# Data_Value_Unit                object
# Data_Value_Type                object
# Data_Value                    float64
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Data_Value_Std_Err            float64
# Low_Confidence_Limit          float64
# High_Confidence_Limit         float64
# Sample_Size                   float64
# Gender                         object
# Race                           object
# Age                            object
# Education                      object
# GeoLocation                    object
# TopicTypeId                    object
# TopicId                        object
# MeasureId                      object
# StratificationID1              object
# StratificationID2              object
# StratificationID3              object
# StratificationID4              object
# SubMeasureID                   object
# DisplayOrder                    int64
# dtype: object

# %% [markdown]
# Cột dữ liệu YEAR đang có kiểu dạng số, ta cần đưa nó về dạng phân loại

# %%
raw_df['YEAR'] = raw_df['YEAR'].astype('object')
dtypes = raw_df.dtypes
float_cols = set(dtypes[(dtypes==np.float32) | (dtypes==np.float64)].index)
object_cols = set(dtypes[dtypes == object].index)
dtypes
# Out:
# YEAR                           object
# LocationAbbr                   object
# LocationDesc                   object
# TopicType                      object
# TopicDesc                      object
# MeasureDesc                    object
# DataSource                     object
# Response                       object
# Data_Value_Unit                object
# Data_Value_Type                object
# Data_Value                    float64
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Data_Value_Std_Err            float64
# Low_Confidence_Limit          float64
# High_Confidence_Limit         float64
# Sample_Size                   float64
# Gender                         object
# Race                           object
# Age                            object
# Education                      object
# GeoLocation                    object
# TopicTypeId                    object
# TopicId                        object
# MeasureId                      object
# StratificationID1              object
# StratificationID2              object
# StratificationID3              object
# StratificationID4              object
# SubMeasureID                   object
# DisplayOrder                    int64
# dtype: object

# %% [markdown]
# #### Ý nghĩa của các cột dữ liệu
# YEAR: năm khảo sát <br>
# LocationAbbr: kí hiệu viết tắt của bang <br>
# LocationDesc: tên bang <br>
# TopicType: kiểu chủ đề khảo sát <br>
# TopicDesc: mô tả chủ đề khảo sát <br>
# MeasureDesc: mô tả đơn vị đo lường <br>
# DataSource: nguồn dữ liệu <br>
# Response: phản hồi khảo sát <br>
# Data_Value_Unit: đơn vị của giá trị dữ liệu <br>
# Data_Value_Type: kiểu của giá trị dữ liệu <br>
# Data_Value: giá trị dữ liệu <br>
# Data_Value_Footnote_Symbol: kí hiệu cước chú <br>
# Data_Value_Footnote: cước chú <br>
# Data_Value_Std_Err: độ lệch chuẩn của giá trị dữ liệu <br>
# Low_Confidence_Limit: giới hạn thấp của độ tin cậy <br>
# High_Confidence_Limit: giới hạn cao của độ tin cậy <br>
# Sample_Size: kích thước mẫu <br>
# Gender: giới tính <br>
# Race: chủng tộc <br>
# Age: độ tuổi <br>
# Education: trình độ học vấn <br>
# GeoLocation: vị trí địa lí <br>
# TopicTypeId: mã định danh của kiểu chủ đề <br>
# TopicId: mã định danh của chủ đề <br>
# MeasureId: mã định danh của độ đo lường <br>
# StratificationID1: mã định danh của sự phân tầng 1 (phân tầng theo giới tính) <br>
# StratificationID2: mã định danh của sự phân tầng 2 (phân tầng theo độ tuổi) <br>
# StratificationID3: mã định danh của sự phân tầng 3 (phân tầng theo chủng tộc) <br>
# StratificationID4: mã định danh của sự phân tầng 4 (phân tầng theo trình độ học vấn) <br>
# SubMeasureID: mã định danh đơn vị đo lường phụ (đo lường theo tần suất, nếu không thì theo giới tính) <br>
# DisplayOrder: mức độ hiển thị ưu tiên <br>

# %% [markdown]
# #### Sự phân bố giá trị của các cột dữ liệu kiểu số

# %%
num_col_info_df = raw_df.select_dtypes(exclude='object')
def missing_ratio(df: pd.DataFrame):
    ratio = df.isnull().sum()/float(len(df)) *100
    return ratio.round(1)

def lower_quartile(df: pd.DataFrame):
    return df.quantile(0.25).round(1)


def median(df: pd.DataFrame):
    return df.quantile(0.5).round(1)


def upper_quartile(df: pd.DataFrame):
    return df.quantile(0.75).round(1)



num_col_info_df = num_col_info_df.agg([missing_ratio, "min", lower_quartile, median, upper_quartile, "max"])

# %% [markdown]
# Tỉ lệ mất mát của mỗi cột dữ liệu kiểu số

# %%
dict(num_col_info_df.iloc[0])
# Out:
# {'Data_Value': 4.9,
#  'Data_Value_Std_Err': 4.9,
#  'Low_Confidence_Limit': 4.9,
#  'High_Confidence_Limit': 4.9,
#  'Sample_Size': 4.9,
#  'DisplayOrder': 0.0}

# %% [markdown]
# Giá trị nhỏ nhất của mỗi cột dữ liệu kiểu số

# %%
dict(num_col_info_df.iloc[1])
# Out:
# {'Data_Value': 0.0,
#  'Data_Value_Std_Err': 0.0,
#  'Low_Confidence_Limit': 0.0,
#  'High_Confidence_Limit': 0.0,
#  'Sample_Size': 50.0,
#  'DisplayOrder': 1.0}

# %% [markdown]
# Tứ phân vị thứ nhất của mỗi cột dữ liệu kiểu số

# %%
dict(num_col_info_df.iloc[2])
# Out:
# {'Data_Value': 3.0,
#  'Data_Value_Std_Err': 0.6,
#  'Low_Confidence_Limit': 1.7,
#  'High_Confidence_Limit': 4.3,
#  'Sample_Size': 671.0,
#  'DisplayOrder': 7.0}

# %% [markdown]
# Trung vị của mỗi cột dữ liệu kiểu số

# %%
dict(num_col_info_df.iloc[3])
# Out:
# {'Data_Value': 10.6,
#  'Data_Value_Std_Err': 1.3,
#  'Low_Confidence_Limit': 7.9,
#  'High_Confidence_Limit': 13.2,
#  'Sample_Size': 1001.0,
#  'DisplayOrder': 9.0}

# %% [markdown]
# Tứ phân vị thứ ba của mỗi cột dữ liệu kiểu số

# %%
dict(num_col_info_df.iloc[4])
# Out:
# {'Data_Value': 36.4,
#  'Data_Value_Std_Err': 2.4,
#  'Low_Confidence_Limit': 29.6,
#  'High_Confidence_Limit': 42.5,
#  'Sample_Size': 1642.0,
#  'DisplayOrder': 11.0}

# %% [markdown]
# Giá trị lớn nhất của mỗi cột dữ liệu kiểu số

# %%
dict(num_col_info_df.iloc[2])
# Out:
# {'Data_Value': 3.0,
#  'Data_Value_Std_Err': 0.6,
#  'Low_Confidence_Limit': 1.7,
#  'High_Confidence_Limit': 4.3,
#  'Sample_Size': 671.0,
#  'DisplayOrder': 7.0}

# %% [markdown]
# ### Loại bỏ cột, dòng dữ liệu
# Trong các cột dữ liệu có các cột cước chú và kí hiệu cước chú. Trước tiên, ta cần xem các dữ liệu chứa kí hiệu cước chú:

# %%
temp_df = raw_df[raw_df['Data_Value_Footnote_Symbol'] == '*']
temp_df
# Out:
#        YEAR LocationAbbr   LocationDesc                  TopicType  \
# 8      2010           AL        Alabama  Tobacco Use – Survey Data
# 35     2012           AL        Alabama  Tobacco Use – Survey Data
# 38     2010           AL        Alabama  Tobacco Use – Survey Data
# 106    2014           AL        Alabama  Tobacco Use – Survey Data
# 110    2014           AL        Alabama  Tobacco Use – Survey Data
# ...     ...          ...            ...                        ...
# 10229  2015           WV  West Virginia  Tobacco Use – Survey Data
# 10467  2015           WV  West Virginia  Tobacco Use – Survey Data
# 10500  2015           WV  West Virginia  Tobacco Use – Survey Data
# 10518  2017           WV  West Virginia  Tobacco Use – Survey Data
# 10527  2017           WV  West Virginia  Tobacco Use – Survey Data
#
#                TopicDesc                                        MeasureDesc  \
# 8      Cessation (Youth)        Percent of Current Smokers Who Want to Quit
# 35     Cessation (Youth)  Quit Attempt in Past Year Among Current Cigare...
# 38     Cessation (Youth)  Quit Attempt in Past Year Among Current Cigare...
# 106    Cessation (Youth)        Percent of Current Smokers Who Want to Quit
# 110    Cessation (Youth)  Quit Attempt in Past Year Among Current Cigare...
# ...                  ...                                                ...
# 10229  Cessation (Youth)        Percent of Current Smokers Who Want to Quit
# 10467  Cessation (Youth)  Quit Attempt in Past Year Among Current Cigare...
# 10500  Cessation (Youth)  Quit Attempt in Past Year Among Current Cigare...
# 10518  Cessation (Youth)  Quit Attempt in Past Year Among Current Cigare...
# 10527  Cessation (Youth)  Quit Attempt in Past Year Among Current Cigare...
#
#       DataSource Response Data_Value_Unit Data_Value_Type  ...  \
# 8            YTS      NaN               %      Percentage  ...
# 35           YTS      NaN               %      Percentage  ...
# 38           YTS      NaN               %      Percentage  ...
# 106          YTS      NaN               %      Percentage  ...
# 110          YTS      NaN               %      Percentage  ...
# ...          ...      ...             ...             ...  ...
# 10229        YTS      NaN               %      Percentage  ...
# 10467        YTS      NaN               %      Percentage  ...
# 10500        YTS      NaN               %      Percentage  ...
# 10518        YTS      NaN               %      Percentage  ...
# 10527        YTS      NaN               %      Percentage  ...
#
#                          GeoLocation TopicTypeId TopicId  MeasureId  \
# 8      (32.840571122, -86.631860762)         BEH  105BEH     170CES
# 35     (32.840571122, -86.631860762)         BEH  105BEH     169QUA
# 38     (32.840571122, -86.631860762)         BEH  105BEH     169QUA
# 106    (32.840571122, -86.631860762)         BEH  105BEH     170CES
# 110    (32.840571122, -86.631860762)         BEH  105BEH     169QUA
# ...                              ...         ...     ...        ...
# 10229  (38.665510202, -80.712640135)         BEH  105BEH     170CES
# 10467  (38.665510202, -80.712640135)         BEH  105BEH     169QUA
# 10500  (38.665510202, -80.712640135)         BEH  105BEH     169QUA
# 10518  (38.665510202, -80.712640135)         BEH  105BEH     169QUA
# 10527  (38.665510202, -80.712640135)         BEH  105BEH     169QUA
#
#        StratificationID1  StratificationID2  StratificationID3  \
# 8                   3GEN               8AGE               6RAC
# 35                  3GEN               8AGE               6RAC
# 38                  3GEN               8AGE               6RAC
# 106                 2GEN               8AGE               6RAC
# 110                 2GEN               8AGE               6RAC
# ...                  ...                ...                ...
# 10229               3GEN               8AGE               6RAC
# 10467               3GEN               8AGE               6RAC
# 10500               2GEN               8AGE               6RAC
# 10518               2GEN               8AGE               6RAC
# 10527               3GEN               8AGE               6RAC
#
#       StratificationID4 SubMeasureID DisplayOrder
# 8                  1EDU        YTS03            3
# 35                 1EDU        YTS06            6
# 38                 1EDU        YTS06            6
# 106                1EDU        YTS02            2
# 110                1EDU        YTS05            5
# ...                 ...          ...          ...
# 10229              1EDU        YTS03            3
# 10467              1EDU        YTS06            6
# 10500              1EDU        YTS05            5
# 10518              1EDU        YTS05            5
# 10527              1EDU        YTS06            6
#
# [517 rows x 31 columns]

# %% [markdown]
# Danh sách các cước chú:

# %%
reason = temp_df['Data_Value_Footnote'].unique()
print(reason)
# Out:
# ['Data in these cells have been suppressed because of a small sample size']

# %% [markdown]
# Có thể thấy, các dòng dữ liệu này bị loại bỏ vì kích thước mẫu nhỏ. Do đó, ta sẽ tiến hành loại các dòng dữ liệu này ra khỏi tập dữ liệu:

# %%
idx_drop_list = raw_df[raw_df['Data_Value_Footnote_Symbol'] == '*'].index
raw_df = raw_df.drop(axis='index', index = idx_drop_list)
raw_df = raw_df.reset_index(drop=True)
raw_df[:20]
# Out:
#     YEAR LocationAbbr LocationDesc                  TopicType  \
# 0   2008           AL      Alabama  Tobacco Use – Survey Data
# 1   2010           AL      Alabama  Tobacco Use – Survey Data
# 2   2002           AL      Alabama  Tobacco Use – Survey Data
# 3   2012           AL      Alabama  Tobacco Use – Survey Data
# 4   2004           AL      Alabama  Tobacco Use – Survey Data
# 5   2000           AL      Alabama  Tobacco Use – Survey Data
# 6   2014           AL      Alabama  Tobacco Use – Survey Data
# 7   2014           AL      Alabama  Tobacco Use – Survey Data
# 8   2010           AL      Alabama  Tobacco Use – Survey Data
# 9   2006           AL      Alabama  Tobacco Use – Survey Data
# 10  2010           AL      Alabama  Tobacco Use – Survey Data
# 11  2002           AL      Alabama  Tobacco Use – Survey Data
# 12  2008           AL      Alabama  Tobacco Use – Survey Data
# 13  2016           AL      Alabama  Tobacco Use – Survey Data
# 14  2006           AL      Alabama  Tobacco Use – Survey Data
# 15  2002           AL      Alabama  Tobacco Use – Survey Data
# 16  2004           AL      Alabama  Tobacco Use – Survey Data
# 17  2008           AL      Alabama  Tobacco Use – Survey Data
# 18  2000           AL      Alabama  Tobacco Use – Survey Data
# 19  2004           AL      Alabama  Tobacco Use – Survey Data
#
#                         TopicDesc  \
# 0           Cigarette Use (Youth)
# 1           Cigarette Use (Youth)
# 2               Cessation (Youth)
# 3               Cessation (Youth)
# 4   Smokeless Tobacco Use (Youth)
# 5               Cessation (Youth)
# 6   Smokeless Tobacco Use (Youth)
# 7               Cessation (Youth)
# 8           Cigarette Use (Youth)
# 9               Cessation (Youth)
# 10              Cessation (Youth)
# 11  Smokeless Tobacco Use (Youth)
# 12          Cigarette Use (Youth)
# 13              Cessation (Youth)
# 14          Cigarette Use (Youth)
# 15          Cigarette Use (Youth)
# 16  Smokeless Tobacco Use (Youth)
# 17  Smokeless Tobacco Use (Youth)
# 18  Smokeless Tobacco Use (Youth)
# 19          Cigarette Use (Youth)
#
#                                           MeasureDesc DataSource  Response  \
# 0                                      Smoking Status        YTS      Ever
# 1                                      Smoking Status        YTS  Frequent
# 2   Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# 3   Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# 4                                         User Status        YTS      Ever
# 5         Percent of Current Smokers Who Want to Quit        YTS       NaN
# 6                                         User Status        YTS  Frequent
# 7         Percent of Current Smokers Who Want to Quit        YTS       NaN
# 8                                      Smoking Status        YTS      Ever
# 9         Percent of Current Smokers Who Want to Quit        YTS       NaN
# 10  Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# 11                                        User Status        YTS      Ever
# 12                                     Smoking Status        YTS   Current
# 13        Percent of Current Smokers Who Want to Quit        YTS       NaN
# 14                                     Smoking Status        YTS      Ever
# 15                                     Smoking Status        YTS   Current
# 16                                        User Status        YTS  Frequent
# 17                                        User Status        YTS   Current
# 18                                        User Status        YTS      Ever
# 19                                     Smoking Status        YTS      Ever
#
#    Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0                %      Percentage  ...  (32.840571122, -86.631860762)
# 1                %      Percentage  ...  (32.840571122, -86.631860762)
# 2                %      Percentage  ...  (32.840571122, -86.631860762)
# 3                %      Percentage  ...  (32.840571122, -86.631860762)
# 4                %      Percentage  ...  (32.840571122, -86.631860762)
# 5                %      Percentage  ...  (32.840571122, -86.631860762)
# 6                %      Percentage  ...  (32.840571122, -86.631860762)
# 7                %      Percentage  ...  (32.840571122, -86.631860762)
# 8                %      Percentage  ...  (32.840571122, -86.631860762)
# 9                %      Percentage  ...  (32.840571122, -86.631860762)
# 10               %      Percentage  ...  (32.840571122, -86.631860762)
# 11               %      Percentage  ...  (32.840571122, -86.631860762)
# 12               %      Percentage  ...  (32.840571122, -86.631860762)
# 13               %      Percentage  ...  (32.840571122, -86.631860762)
# 14               %      Percentage  ...  (32.840571122, -86.631860762)
# 15               %      Percentage  ...  (32.840571122, -86.631860762)
# 16               %      Percentage  ...  (32.840571122, -86.631860762)
# 17               %      Percentage  ...  (32.840571122, -86.631860762)
# 18               %      Percentage  ...  (32.840571122, -86.631860762)
# 19               %      Percentage  ...  (32.840571122, -86.631860762)
#
#    TopicTypeId TopicId  MeasureId  StratificationID1  StratificationID2  \
# 0          BEH  106BEH     166SSA               3GEN               8AGE
# 1          BEH  106BEH     166SSA               3GEN               8AGE
# 2          BEH  105BEH     169QUA               3GEN               8AGE
# 3          BEH  105BEH     169QUA               2GEN               8AGE
# 4          BEH  151BEH     169USS               2GEN               8AGE
# 5          BEH  105BEH     170CES               3GEN               8AGE
# 6          BEH  151BEH     169USS               1GEN               8AGE
# 7          BEH  105BEH     170CES               1GEN               8AGE
# 8          BEH  106BEH     166SSA               3GEN               8AGE
# 9          BEH  105BEH     170CES               3GEN               8AGE
# 10         BEH  105BEH     169QUA               1GEN               8AGE
# 11         BEH  151BEH     169USS               3GEN               8AGE
# 12         BEH  106BEH     166SSA               1GEN               8AGE
# 13         BEH  105BEH     170CES               3GEN               8AGE
# 14         BEH  106BEH     166SSA               1GEN               8AGE
# 15         BEH  106BEH     166SSA               1GEN               8AGE
# 16         BEH  151BEH     169USS               1GEN               8AGE
# 17         BEH  151BEH     169USS               1GEN               8AGE
# 18         BEH  151BEH     169USS               2GEN               8AGE
# 19         BEH  106BEH     166SSA               3GEN               8AGE
#
#     StratificationID3 StratificationID4 SubMeasureID DisplayOrder
# 0                6RAC              2EDU        YTS08            8
# 1                6RAC              2EDU        YTS09            9
# 2                6RAC              2EDU        YTS06            6
# 3                6RAC              2EDU        YTS05            5
# 4                6RAC              1EDU        YTS11           11
# 5                6RAC              2EDU        YTS03            3
# 6                6RAC              1EDU        YTS12           12
# 7                6RAC              2EDU        YTS01            1
# 8                6RAC              1EDU        YTS08            8
# 9                6RAC              2EDU        YTS03            3
# 10               6RAC              2EDU        YTS04            4
# 11               6RAC              2EDU        YTS11           11
# 12               6RAC              1EDU        YTS07            7
# 13               6RAC              2EDU        YTS03            3
# 14               6RAC              1EDU        YTS08            8
# 15               6RAC              1EDU        YTS07            7
# 16               6RAC              2EDU        YTS12           12
# 17               6RAC              2EDU        YTS10           10
# 18               6RAC              1EDU        YTS11           11
# 19               6RAC              1EDU        YTS08            8
#
# [20 rows x 31 columns]

# %% [markdown]
# Sau khi đã loại bỏ các dòng dữ liệu, ta sẽ tiến hành loại bỏ hai cột Data_Value_Footnote_Symbol và Data_Value_Footnote do lúc này hai cột này đã không còn dữ liệu

# %%
raw_df.drop(['Data_Value_Footnote_Symbol','Data_Value_Footnote'], axis=1, inplace=True)
raw_df.head()
# Out:
#    YEAR LocationAbbr LocationDesc                  TopicType  \
# 0  2008           AL      Alabama  Tobacco Use – Survey Data
# 1  2010           AL      Alabama  Tobacco Use – Survey Data
# 2  2002           AL      Alabama  Tobacco Use – Survey Data
# 3  2012           AL      Alabama  Tobacco Use – Survey Data
# 4  2004           AL      Alabama  Tobacco Use – Survey Data
#
#                        TopicDesc  \
# 0          Cigarette Use (Youth)
# 1          Cigarette Use (Youth)
# 2              Cessation (Youth)
# 3              Cessation (Youth)
# 4  Smokeless Tobacco Use (Youth)
#
#                                          MeasureDesc DataSource  Response  \
# 0                                     Smoking Status        YTS      Ever
# 1                                     Smoking Status        YTS  Frequent
# 2  Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# 3  Quit Attempt in Past Year Among Current Cigare...        YTS       NaN
# 4                                        User Status        YTS      Ever
#
#   Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0               %      Percentage  ...  (32.840571122, -86.631860762)
# 1               %      Percentage  ...  (32.840571122, -86.631860762)
# 2               %      Percentage  ...  (32.840571122, -86.631860762)
# 3               %      Percentage  ...  (32.840571122, -86.631860762)
# 4               %      Percentage  ...  (32.840571122, -86.631860762)
#
#    TopicTypeId  TopicId  MeasureId  StratificationID1 StratificationID2  \
# 0          BEH   106BEH     166SSA               3GEN              8AGE
# 1          BEH   106BEH     166SSA               3GEN              8AGE
# 2          BEH   105BEH     169QUA               3GEN              8AGE
# 3          BEH   105BEH     169QUA               2GEN              8AGE
# 4          BEH   151BEH     169USS               2GEN              8AGE
#
#   StratificationID3 StratificationID4 SubMeasureID DisplayOrder
# 0              6RAC              2EDU        YTS08            8
# 1              6RAC              2EDU        YTS09            9
# 2              6RAC              2EDU        YTS06            6
# 3              6RAC              2EDU        YTS05            5
# 4              6RAC              1EDU        YTS11           11
#
# [5 rows x 29 columns]

# %% [markdown]
# Kế tiếp, vài dòng dữ liệu sẽ không chứa giá trị ở cột Response do mục đích của khảo sát không sử dụng đến cột dữ liệu này. Do tỉ lệ mất mát của dòng không quá nhiều nên ta sẽ tiến hành điền None vào các chỗ trống này.

# %%
raw_df['Response'].fillna('None', inplace=True)
raw_df['Response'].unique()
# Out:
# C:\Users\WIN 10\AppData\Local\Temp\ipykernel_16116\3003041007.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   raw_df['Response'].fillna('None', inplace=True)
# array(['Ever', 'Frequent', 'None', 'Current'], dtype=object)

# %% [markdown]
# Ta kiểm tra lại dữ liệu và các số liệu thống kê. Lúc này, tập dữ liệu đã có thể được sử dụng để trực quan hóa.

# %%
raw_df.head(15)
# Out:
#     YEAR LocationAbbr LocationDesc                  TopicType  \
# 0   2008           AL      Alabama  Tobacco Use – Survey Data
# 1   2010           AL      Alabama  Tobacco Use – Survey Data
# 2   2002           AL      Alabama  Tobacco Use – Survey Data
# 3   2012           AL      Alabama  Tobacco Use – Survey Data
# 4   2004           AL      Alabama  Tobacco Use – Survey Data
# 5   2000           AL      Alabama  Tobacco Use – Survey Data
# 6   2014           AL      Alabama  Tobacco Use – Survey Data
# 7   2014           AL      Alabama  Tobacco Use – Survey Data
# 8   2010           AL      Alabama  Tobacco Use – Survey Data
# 9   2006           AL      Alabama  Tobacco Use – Survey Data
# 10  2010           AL      Alabama  Tobacco Use – Survey Data
# 11  2002           AL      Alabama  Tobacco Use – Survey Data
# 12  2008           AL      Alabama  Tobacco Use – Survey Data
# 13  2016           AL      Alabama  Tobacco Use – Survey Data
# 14  2006           AL      Alabama  Tobacco Use – Survey Data
#
#                         TopicDesc  \
# 0           Cigarette Use (Youth)
# 1           Cigarette Use (Youth)
# 2               Cessation (Youth)
# 3               Cessation (Youth)
# 4   Smokeless Tobacco Use (Youth)
# 5               Cessation (Youth)
# 6   Smokeless Tobacco Use (Youth)
# 7               Cessation (Youth)
# 8           Cigarette Use (Youth)
# 9               Cessation (Youth)
# 10              Cessation (Youth)
# 11  Smokeless Tobacco Use (Youth)
# 12          Cigarette Use (Youth)
# 13              Cessation (Youth)
# 14          Cigarette Use (Youth)
#
#                                           MeasureDesc DataSource  Response  \
# 0                                      Smoking Status        YTS      Ever
# 1                                      Smoking Status        YTS  Frequent
# 2   Quit Attempt in Past Year Among Current Cigare...        YTS      None
# 3   Quit Attempt in Past Year Among Current Cigare...        YTS      None
# 4                                         User Status        YTS      Ever
# 5         Percent of Current Smokers Who Want to Quit        YTS      None
# 6                                         User Status        YTS  Frequent
# 7         Percent of Current Smokers Who Want to Quit        YTS      None
# 8                                      Smoking Status        YTS      Ever
# 9         Percent of Current Smokers Who Want to Quit        YTS      None
# 10  Quit Attempt in Past Year Among Current Cigare...        YTS      None
# 11                                        User Status        YTS      Ever
# 12                                     Smoking Status        YTS   Current
# 13        Percent of Current Smokers Who Want to Quit        YTS      None
# 14                                     Smoking Status        YTS      Ever
#
#    Data_Value_Unit Data_Value_Type  ...                    GeoLocation  \
# 0                %      Percentage  ...  (32.840571122, -86.631860762)
# 1                %      Percentage  ...  (32.840571122, -86.631860762)
# 2                %      Percentage  ...  (32.840571122, -86.631860762)
# 3                %      Percentage  ...  (32.840571122, -86.631860762)
# 4                %      Percentage  ...  (32.840571122, -86.631860762)
# 5                %      Percentage  ...  (32.840571122, -86.631860762)
# 6                %      Percentage  ...  (32.840571122, -86.631860762)
# 7                %      Percentage  ...  (32.840571122, -86.631860762)
# 8                %      Percentage  ...  (32.840571122, -86.631860762)
# 9                %      Percentage  ...  (32.840571122, -86.631860762)
# 10               %      Percentage  ...  (32.840571122, -86.631860762)
# 11               %      Percentage  ...  (32.840571122, -86.631860762)
# 12               %      Percentage  ...  (32.840571122, -86.631860762)
# 13               %      Percentage  ...  (32.840571122, -86.631860762)
# 14               %      Percentage  ...  (32.840571122, -86.631860762)
#
#     TopicTypeId  TopicId  MeasureId  StratificationID1 StratificationID2  \
# 0           BEH   106BEH     166SSA               3GEN              8AGE
# 1           BEH   106BEH     166SSA               3GEN              8AGE
# 2           BEH   105BEH     169QUA               3GEN              8AGE
# 3           BEH   105BEH     169QUA               2GEN              8AGE
# 4           BEH   151BEH     169USS               2GEN              8AGE
# 5           BEH   105BEH     170CES               3GEN              8AGE
# 6           BEH   151BEH     169USS               1GEN              8AGE
# 7           BEH   105BEH     170CES               1GEN              8AGE
# 8           BEH   106BEH     166SSA               3GEN              8AGE
# 9           BEH   105BEH     170CES               3GEN              8AGE
# 10          BEH   105BEH     169QUA               1GEN              8AGE
# 11          BEH   151BEH     169USS               3GEN              8AGE
# 12          BEH   106BEH     166SSA               1GEN              8AGE
# 13          BEH   105BEH     170CES               3GEN              8AGE
# 14          BEH   106BEH     166SSA               1GEN              8AGE
#
#    StratificationID3 StratificationID4 SubMeasureID DisplayOrder
# 0               6RAC              2EDU        YTS08            8
# 1               6RAC              2EDU        YTS09            9
# 2               6RAC              2EDU        YTS06            6
# 3               6RAC              2EDU        YTS05            5
# 4               6RAC              1EDU        YTS11           11
# 5               6RAC              2EDU        YTS03            3
# 6               6RAC              1EDU        YTS12           12
# 7               6RAC              2EDU        YTS01            1
# 8               6RAC              1EDU        YTS08            8
# 9               6RAC              2EDU        YTS03            3
# 10              6RAC              2EDU        YTS04            4
# 11              6RAC              2EDU        YTS11           11
# 12              6RAC              1EDU        YTS07            7
# 13              6RAC              2EDU        YTS03            3
# 14              6RAC              1EDU        YTS08            8
#
# [15 rows x 29 columns]

# %%
raw_df.select_dtypes(exclude='object').agg([missing_ratio, "min", lower_quartile, median, upper_quartile, "max"])
# Out:
#                 Data_Value  Data_Value_Std_Err  Low_Confidence_Limit  \
# missing_ratio          0.0                 0.0                   0.0
# min                    0.0                 0.0                   0.0
# lower_quartile         3.0                 0.6                   1.7
# median                10.6                 1.3                   7.9
# upper_quartile        36.4                 2.4                  29.6
# max                   98.0                16.1                  97.6
#
#                 High_Confidence_Limit  Sample_Size  DisplayOrder
# missing_ratio                     0.0          0.0           0.0
# min                               0.0         50.0           1.0
# lower_quartile                    4.3        671.0           7.0
# median                           13.2       1001.0           9.0
# upper_quartile                   42.5       1642.0          11.0
# max                              98.4      36910.0          12.0

# %% [markdown]
# ### Ghi tập dữ liệu vào tập tin
# Ta kiểm tra lại các cột dữ liệu trước khi tiến hành ghi:

# %%
print(f"Total number of features: {raw_df.shape[1]}")
raw_df.dtypes
# Out:
# Total number of features: 29
# YEAR                      object
# LocationAbbr              object
# LocationDesc              object
# TopicType                 object
# TopicDesc                 object
# MeasureDesc               object
# DataSource                object
# Response                  object
# Data_Value_Unit           object
# Data_Value_Type           object
# Data_Value               float64
# Data_Value_Std_Err       float64
# Low_Confidence_Limit     float64
# High_Confidence_Limit    float64
# Sample_Size              float64
# Gender                    object
# Race                      object
# Age                       object
# Education                 object
# GeoLocation               object
# TopicTypeId               object
# TopicId                   object
# MeasureId                 object
# StratificationID1         object
# StratificationID2         object
# StratificationID3         object
# StratificationID4         object
# SubMeasureID              object
# DisplayOrder               int64
# dtype: object

# %% [markdown]
# Ghi tập dữ liệu vào tập tin

# %%
raw_df.to_csv('Data\\processed_data_tobacco.csv', index=False)
